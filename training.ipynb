# %% [markdown]
# # Training Face Encodings

# %%
import pandas as pd
import face_recognition

# %%
import os
import face_recognition
import shutil
# Directory containing folders, each with images
root_dir = 'Augmented_Faces'
output_dir = "Augmented_Clean_Faces"
# Initialize the lists to store face encodings and labels
face_encodings = []
labels = []

# Loop through each folder in the root directory
for label in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, label)
    if os.path.isdir(folder_path):
        # Find image files in the folder
        for filename in os.listdir(folder_path):
            if filename.endswith('.jpeg') or filename.endswith('.png'):
                # Load the image
                image_path = os.path.join(folder_path, filename)
                image = face_recognition.load_image_file(image_path)

                # Find face locations and encodings
                face_locations = face_recognition.face_locations(image)
                curr_face_encodings = face_recognition.face_encodings(image, face_locations)

                if len(curr_face_encodings) > 0:
                    # Append the first face encoding from each image
                    face_encodings.append(curr_face_encodings[0])
                    # Append the folder's name as label
                    labels.append(label)
                    output_path = os.path.join(output_dir, label, filename)
                    os.makedirs(os.path.dirname(output_path), exist_ok=True)
                    shutil.copyfile(image_path, output_path)
                else:
                    print(f'Error: No face found in {label}/{filename}')

# Print the face encodings and labels
print(face_encodings)
print(labels)
# Out:
# Error: No face found in 27-Karpe Sai/aug_0_6384.jpeg
# Error: No face found in 27-Karpe Sai/aug_0_6982.jpeg
# Error: No face found in 27-Karpe Sai/aug_0_8164.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_3221.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_3922.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_4909.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_4939.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_6259.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_6689.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_8332.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_8837.jpeg
# Error: No face found in 29-Kasar Utkarsha/aug_0_999.jpeg
# Error: No face found in 32-Kshirsagar Prasad/aug_0_7304.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_1069.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_1809.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_2034.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_2046.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_2561.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_2669.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_2789.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_3962.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_4180.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_4400.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_4447.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_5004.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_5783.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_806.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_8364.jpeg
# Error: No face found in 35-Mahanur Aniket/aug_0_8698.jpeg
# Error: No face found in 36-Mate Sanskruti/aug_0_4421.jpeg
# Error: No face found in 36-Mate Sanskruti/aug_0_4827.jpeg
# Error: No face found in 36-Mate Sanskruti/aug_0_5642.jpeg
# Error: No face found in 36-Mate Sanskruti/aug_0_9683.jpeg
# Error: No face found in 37-Mhalaskar Sayali/aug_0_1954.jpeg
# Error: No face found in 37-Mhalaskar Sayali/aug_0_6481.jpeg
# Error: No face found in 40-Nawale Sakshi/aug_0_2832.jpeg
# Error: No face found in 40-Nawale Sakshi/aug_0_3376.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_1863.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_2334.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_242.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_3300.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_3930.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_4900.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_4941.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_5394.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_5669.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_6738.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_6924.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_7377.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_8051.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_8785.jpeg
# Error: No face found in 44-Patil Utkarsh/aug_0_9756.jpeg
# Error: No face found in 45-Pawar Pranjal/aug_0_5637.jpeg
# Error: No face found in 46-Pawar Shivraj/aug_0_3646.jpeg
# Error: No face found in 46-Pawar Shivraj/aug_0_423.jpeg
# Error: No face found in 46-Pawar Shivraj/aug_0_6481.jpeg
# Error: No face found in 46-Pawar Shivraj/aug_0_7889.jpeg
# Error: No face found in 46-Pawar Shivraj/aug_0_8160.jpeg
# Error: No face found in 46-Pawar Shivraj/aug_0_8344.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_124.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_2.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_2638.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_4480.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_7318.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_8454.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_9217.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_948.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_9707.jpeg
# Error: No face found in Dr.D.G .Lokhande/aug_0_9810.jpeg
# [array([-2.02388331e-01,  1.13177612e-01,  4.78915200e-02, -3.44484970e-02,
#        -5.66609763e-02, -5.48721775e-02,  3.09195369e-04, -1.07738934e-01,
#         1.80999160e-01, -1.19738348e-01,  2.42250234e-01, -2.57707611e-02,
#        -1.98293909e-01, -3.52346748e-02, -5.47467591e-03,  1.21214762e-01,
#        -0.34868309, -0.10267247, -0.12736005,  0.00577462, -0.01172786,
#         0.08632199,  0.06273717, -0.20697479, -0.02914507, -0.03340176,
#        -0.00481994,  0.0584638 ,  0.01828606,  0.2055615 ,  0.03672316,
#        -0.16205795, -0.02206711, -0.00216117,  0.25352329,  0.13437498,
#        -0.0250658 ,  0.00040851,  0.01715471, -0.01065589, -0.26850575,
#         0.07178544,  0.10078604,  0.07400393,  0.04201903,  0.08487363,
#        -0.07398972, -0.01673254,  0.03037123, -0.18638615,  0.02100118,
#         0.02487521, -0.08728091, -0.12589028, -0.04048773,  0.19191371,
#         0.11384732, -0.10606901, -0.08314464,  0.15195121, -0.12419215,
#        -0.01499216,  0.04029559, -0.1278079 , -0.09745228, -0.28024647,
#         0.09508806,  0.39301178,  0.0838681 , -0.17419884,  0.02713028,
#        -0.16309518,  0.03059362,  0.0625654 , -0.0241444 , -0.04224897,
#         0.06420025, -0.07911496,  0.1147927 ,  0.09727752, -0.06556685,
#        -0.10249259,  0.20285943, -0.07848221,  0.04277486,  0.02657082,
#         0.00071328, -0.00128308, -0.03629168, -0.14957458,  0.02424761,
#         0.11504605, -0.07309172, -0.0237189 ,  0.09399308, -0.17638382,
#         0.08522286,  0.01688018, -0.08121119,  0.02683309,  0.04917779,
#        -0.08689614, -0.04264533,  0.10060707, -0.2114424 ,  0.18478616,
#         0.17892486, -0.031764  ,  0.11905275,  0.02802044,  0.02137833,
#        -0.02202368, -0.04064656, -0.17361921, -0.07357608,  0.04071017,
#         0.09260273, -0.00127612,  0.01268426])]
# ['25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '25-Kanade Pratiksha', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '26-Kardile Abhijit', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '27-Karpe Sai', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shweta', '28-Kasar Shw ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
import os

# Directory containing folders, each with images
input_dir = 'updated_students'
output_dir = 'Augmented_Faces'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Initialize the ImageDataGenerator for augmentation
datagen = ImageDataGenerator(
    rotation_range=0,  # No rotation
    width_shift_range=0.1,  # Random horizontal shift by 10%
    height_shift_range=0.1,  # Random vertical shift by 10%
    shear_range=0,  # No shearing
    zoom_range=0.1,  # Random zoom by 10%
    horizontal_flip=False,  # No horizontal flip
    vertical_flip=False,  # No vertical flip
    fill_mode='nearest'  # Fill mode for pixels outside the boundaries
)

# Loop through each folder in the input directory
for label in os.listdir(input_dir):
    folder_path = os.path.join(input_dir, label)
    if os.path.isdir(folder_path):
        # Create the output directory for the label if it doesn't exist
        output_label_dir = os.path.join(output_dir, label)
        if not os.path.exists(output_label_dir):
            os.makedirs(output_label_dir)

        # Find image files in the folder
        for filename in os.listdir(folder_path):
            if filename.endswith('.jpeg') or filename.endswith('.png'):
                # Load the image
                image_path = os.path.join(folder_path, filename)

                # Generate augmented images
                img = load_img(image_path)
                x = img_to_array(img)
                x = x.reshape((1,) + x.shape)
                i = 0
                for batch in datagen.flow(x, batch_size=1, save_to_dir=output_label_dir, save_prefix='aug', save_format='jpeg'):
                    i += 1
                    if i >= 10:  # Generate 10 augmented images per original image
                        break

print("Data augmentation completed.")
# Out:
# Data augmentation completed.

# %%
from collections import Counter

# Assuming labels is a list
label_counts = Counter(labels)

# Get unique labels and their counts
unique_labels = list(label_counts.keys())
counts = list(label_counts.values())

# Print unique labels and their counts
for label, count in zip(unique_labels, counts):
    print(f"Label: {label}, Count: {count}")
# Out:
# Label: 25-Kanade Pratiksha, Count: 40
# Label: 26-Kardile Abhijit, Count: 80
# Label: 27-Karpe Sai, Count: 27
# Label: 28-Kasar Shweta, Count: 80
# Label: 29-Kasar Utkarsha, Count: 40
# Label: 30-Kaire Vedanshu, Count: 50
# Label: 32-Kshirsagar Prasad, Count: 59
# Label: 33-Kolte Aishwarya, Count: 80
# Label: 34-Magar Nikita, Count: 60
# Label: 35-Mahanur Aniket, Count: 24
# Label: 36-Mate Sanskruti, Count: 65
# Label: 37-Mhalaskar Sayali, Count: 78
# Label: 39-More Sanika, Count: 80
# Label: 40-Nawale Sakshi, Count: 78
# Label: 42-Panghavan Kshitij, Count: 80
# Label: 43-Panghavane Pradnya, Count: 100
# Label: 44-Patil Utkarsh, Count: 104
# Label: 45-Pawar Pranjal, Count: 78
# Label: 46-Pawar Shivraj, Count: 44
# Label: Dr.D.G .Lokhande, Count: 30

# %%
unknown_image = face_recognition.load_image_file("test3.png")
unknown_face_encodings = face_recognition.face_encodings(unknown_image)

# Iterate through faces found in the unknown image
for unknown_face_encoding in unknown_face_encodings:
    # See if the face is a match for the known face(s)
    results = face_recognition.compare_faces(face_encodings, unknown_face_encoding)

    name = "Unknown"
    for i, result in enumerate(results):
        if result:
            name = labels[i]
            break

    print(f"Found {name} in the photo!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 unknown_image = face_recognition.load_image_file("test3.png")
#       2 unknown_face_encodings = face_recognition.face_encodings(unknown_image)
#       4 # Iterate through faces found in the unknown image
#
# NameError: name 'face_recognition' is not defined

# %%
from sklearn.svm import SVC
import numpy as np

# Assuming you have the face_encodings and labels lists from the previous step

# Convert the lists to numpy arrays
X_train = np.array(face_encodings)
y_train = np.array(labels)

# Create and train the SVM classifier
svm_clf = SVC(kernel='linear', probability=True)
svm_clf.fit(X_train, y_train)

# Save the trained SVM classifier (optional)
# You can save the classifier to a file for future use
# For example, using pickle:
import pickle
with open('svm_classifier_mega.pkl', 'wb') as f:
    pickle.dump(svm_clf, f)

print("SVM classifier trained successfully.")
# Out:
# SVM classifier trained successfully.

# %%
import face_recognition
import numpy as np
import os
from sklearn.svm import SVC
import pickle

# # Load the trained SVM classifier
with open('svm_classifier_mega.pkl', 'rb') as f:
    svm_clf = pickle.load(f)

# Load the input image
input_image_path = 'test5.png'
input_image = face_recognition.load_image_file(input_image_path)

# Find face locations and encodings in the input image
face_locations = face_recognition.face_locations(input_image)
input_face_encodings = face_recognition.face_encodings(input_image, face_locations)

# Assuming each image contains only one face
if len(input_face_encodings) == 1:
    # Use the first face encoding (assuming only one face per image)
    input_face_encoding = input_face_encodings[0]

    # Make the prediction using the SVM classifier
    label = svm_clf.predict([input_face_encoding])[0]
    print(f'The predicted label for the input image is: {label}')
else:
    print('Error: Expected 1 face in the input image, found ',len(input_face_encodings) ,'faces.')
# Out:
# The predicted label for the input image is: 34-Magar Nikita

# %%
import cv2
import face_recognition

from ultralytics import YOLO

# Load the YOLOv8 model
# Open the video file
video_path = "C:/Users/pytho/Downloads/face detection[1].mp4"
cap = cv2.VideoCapture(0)


# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

     # Resize the frame to improve processing speed
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    # Find face locations in the frame
    face_locations = face_recognition.face_locations(small_frame)

    # Extract face encodings from the frame
    face_encodings = face_recognition.face_encodings(small_frame, face_locations)

    # Loop through each face in the frame
    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        # Predict the label for the face using the SVM classifier
        label = svm_clf.predict([face_encoding])[0]

        # Resize the face location back to the original frame size
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Draw a box around the face and label it
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
        cv2.putText(frame, label, (left + 6, bottom - 6), cv2.FONT_HERSHEY_DUPLEX, 1.0, (255, 255, 255), 1)

    # Display the frame
    cv2.imshow('Video', frame)

        # Pause the video if 'p' key is pressed
    key = cv2.waitKey(1) & 0xFF
    if key == ord("p"):
        cv2.waitKey(-1)  # Wait indefinitely until any key is pressed
    elif key == ord("q"):
        break
    else:
        # Break the loop if the end of the video is reached
        break
    
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import face_recognition
import numpy as np
from sklearn.svm import SVC
import pickle
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n-face.pt')


# # Load the trained SVM classifier
with open('svm_classifier.pkl', 'rb') as f:
    svm_clf = pickle.load(f)

# Load the video stream
video_path = "C:/Users/pytho/Downloads/face detection[1].mp4"
cap = cv2.VideoCapture(0)
# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        #small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)
        results = model.track(frame,conf=0.90 , persist=True,)

        annotated_frame = results[0].plot()
        print(results[0].boxes.xyxy.to('cpu').tolist())

        face_locations = face_recognition.face_locations(frame)

        face_encodings = face_recognition.face_encodings(frame, face_locations)
        for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        # Predict the label for the face using the SVM classifier
            label = svm_clf.predict([face_encoding])[0]

            top *= 4
            right *= 4
            bottom *= 4
            left *= 4

        # Draw a box around the face and label it
            cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
            cv2.putText(frame, label, (left + 6, bottom - 6), cv2.FONT_HERSHEY_DUPLEX, 1.0, (255, 255, 255), 1)
            print(label)

        cv2.imshow('Video', frame)
        # Pause the video if 'p' key is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord("p"):
            cv2.waitKey(-1)  # Wait indefinitely until any key is pressed
        elif key == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 78.3ms
# Speed: 20.3ms preprocess, 78.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# []
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.22 🚀 Python-3.9.10 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# Setup complete ✅ (12 CPUs, 31.9 GB RAM, 507.1/931.5 GB disk)

# %%
import cv2
import face_recognition
import numpy as np
from sklearn.svm import SVC
import pickle
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n-face.pt')

# Load the trained SVM classifier
with open('svm_classifier.pkl', 'rb') as f:
    svm_clf = pickle.load(f)

# Load the video stream
video_path = "C:/Users/pytho/Downloads/face detection[1].mp4"
cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, conf=0.70,classes = 0, persist=True)

        annotated_frame = results[0].plot()
        print(results[0].boxes)
        bbox = results[0].boxes.xyxy.to('cpu').tolist()
        print(bbox)
        #face_locations = face_recognition.face_locations(frame)
        if bbox != []:
            x1, y1, x2, y2 = bbox[0]
            print(x1,y1,x2,y2)

            
        cv2.imshow('Video', annotated_frame)
        
        # Pause the video if 'p' key is pressed
        key = cv2.waitKey(1) & 0xFF

        if key == ord("p"):
            cv2.waitKey(-1)  # Wait indefinitely until any key is pressed
        elif key == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7589])
# data: tensor([[303.1409, 235.9686, 473.8015, 464.6499,   1.0000,   0.7589,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([
1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8013])
# data: tensor([[184.4010, 184.6745, 345.6061, 406.2898,   1.0000,   0.8013,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[265.0036, 295.4821, 161.2051, 221.6153]])
# xywhn: tensor([[0.4141, 0.6156, 0.2519, 0.4617]])
# xyxy: tensor([[184.4010, 184.6745, 345.6061, 406.2898]])
# xyxyn: tensor([[0.2881, 0.3847, 0.5400, 0.8464]])
# [[184.4010009765625, 184.67449951171875, 345.60614013671875, 406.2897644042969]]
# 184.4010009765625 184.67449951171875 345.60614013671875 406.2897644042969
#
# 0: 480x640 1 face, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8013])
# data: tensor([[181.6026, 185.7655, 341.1500, 407.8889,   1.0000,   0.8013,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[261.3763, 296.8271, 159.5474, 222.1234]])
# xywhn: tensor([[0.4084, 0.6184, 0.2493, 0.4628]])
# xyxy: tensor([[181.6026, 185.7655, 341.1500, 407.8889]])
# xyxyn: tensor([[0.2838, 0.3870, 0.5330, 0.8498]])
# [[181.60264587402344, 185.76547241210938, 341.1500244140625, 407.88885498046875]]
# 181.60264587402344 185.76547241210938 341.1500244140625 407.88885498046875
#
# 0: 480x640 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7985])
# data: tensor([[177.6372, 189.2975, 337.4889, 408.8246,   1.0000,   0.7985,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[257.5630, 299.0611, 159.8517, 219.5272]])
# xywhn: tensor([[0.4024, 0.6230, 0.2498, 0.4573]])
# xyxy: tensor([[177.6372, 189.2975, 337.4889, 408.8246]])
# xyxyn: tensor([[0.2776, 0.3944, 0.5273, 0.8517]])
# [[177.63719177246094, 189.29747009277344, 337.4888610839844, 408.82464599609375]]
# 177.63719177246094 189.29747009277344 337.4888610839844 408.82464599609375
#
# 0: 480x640 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7939])
# data: tensor([[179.3076, 191.0709, 337.5529, 406.9106,   1.0000,   0.7939,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[258.4303, 298.9907, 158.2453, 215.8397]])
# xywhn: tensor([[0.4038, 0.6229, 0.2473, 0.4497]])
# xyxy: tensor([[179.3076, 191.0709, 337.5529, 406.9106]])
# xyxyn: tensor([[0.2802, 0.3981, 0.5274, 0.8477]])
# [[179.3076171875, 191.0708770751953, 337.55291748046875, 406.91058349609375]]
# 179.3076171875 191.0708770751953 337.55291748046875 406.91058349609375
#
# 0: 480x640 2 faces, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0.])
# conf: tensor([0.8457, 0.7029])
# data: tensor([[190.7384, 190.8165, 348.4737, 398.3694,   1.0000,   0.8457,   0.0000],
#         [407.7338, 282.7848, 445.6937, 328.0254,   3.0000,   0.7029,   0.0000]])
# id: tensor([1., 3.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([2, 7])
# xywh: tensor([[269.6060, 294.5929, 157.7353, 207.5528],
#         [426.7137, 305.4051,  37.9599,  45.2406]])
# xywhn: tensor([[0.4213, 0.6137, 0.2465, 0.4324],
#         [0.6667, 0.6363, 0.0593, 0.0943]])
# xyxy: tensor([[190.7384, 190.8165, 348.4737, 398.3694],
#         [407.7338, 282.7848, 445.6937, 328.0254]])
# xyxyn: tensor([[0.2980, 0.3975, 0.5445, 0.8299],
#         [0.6371, 0.5891, 0.6964, 0.6834]])
# [[190.7383575439453, 190.81651306152344, 348.47369384765625, 398.3693542480469], [407.7337951660156, 282.7848205566406, 445.6936950683594, 328.0254211425781]]
# 190.7383575439453 190.81651306152344 348.47369384765625 398.3693542480469
#
# 0: 480x640 1 face, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8131])
# data: tensor([[205.2058, 185.9179, 363.9041, 395.1278,   1.0000,   0.8131,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[284.5550, 290.5228, 158.6984, 209.2099]])
# xywhn: tensor([[0.4446, 0.6053, 0.2480, 0.4359]])
# xyxy: tensor([[205.2058, 185.9179, 363.9041, 395.1278]])
# xyxyn: tensor([[0.3206, 0.3873, 0.5686, 0.8232]])
# [[205.2057647705078, 185.91786193847656, 363.9041442871094, 395.1278076171875]]
# 205.2057647705078 185.91786193847656 363.9041442871094 395.1278076171875
#
# 0: 480x640 1 face, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8365])
# data: tensor([[212.9845, 181.3622, 380.9397, 392.7292,   1.0000,   0.8365,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[296.9621, 287.0457, 167.9552, 211.3670]])
# xywhn: tensor([[0.4640, 0.5980, 0.2624, 0.4403]])
# xyxy: tensor([[212.9845, 181.3622, 380.9397, 392.7292]])
# xyxyn: tensor([[0.3328, 0.3778, 0.5952, 0.8182]])
# [[212.98446655273438, 181.36219787597656, 380.939697265625, 392.7291564941406]]
# 212.98446655273438 181.36219787597656 380.939697265625 392.7291564941406
#
# 0: 480x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7263])
# data: tensor([[252.4891, 184.5684, 405.1025, 392.5831,   1.0000,   0.7263,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[328.7958, 288.5757, 152.6134, 208.0147]])
# xywhn: tensor([[0.5137, 0.6012, 0.2385, 0.4334]])
# xyxy: tensor([[252.4891, 184.5684, 405.1025, 392.5831]])
# xyxyn: tensor([[0.3945, 0.3845, 0.6330, 0.8179]])
# [[252.4890594482422, 184.56837463378906, 405.1025085449219, 392.5830993652344]]
# 252.4890594482422 184.56837463378906 405.1025085449219 392.5830993652344
#
# 0: 480x640 1 face, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7344])
# data: tensor([[278.0417, 189.2170, 433.3847, 395.3571,   1.0000,   0.7344,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[355.7132, 292.2870, 155.3430, 206.1401]])
# xywhn: tensor([[0.5558, 0.6089, 0.2427, 0.4295]])
# xyxy: tensor([[278.0417, 189.2170, 433.3847, 395.3571]])
# xyxyn: tensor([[0.4344, 0.3942, 0.6772, 0.8237]])
# [[278.0417175292969, 189.21697998046875, 433.3847351074219, 395.3570861816406]]
# 278.0417175292969 189.21697998046875 433.3847351074219 395.3570861816406
#
# 0: 480x640 1 face, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7466])
# data: tensor([[308.2991, 200.0442, 463.0902, 401.8716,   1.0000,   0.7466,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[385.6946, 300.9579, 154.7911, 201.8273]])
# xywhn: tensor([[0.6026, 0.6270, 0.2419, 0.4205]])
# xyxy: tensor([[308.2991, 200.0442, 463.0902, 401.8716]])
# xyxyn: tensor([[0.4817, 0.4168, 0.7236, 0.8372]])
# [[308.2991027832031, 200.04421997070312, 463.0901794433594, 401.8715515136719]]
# 308.2991027832031 200.04421997070312 463.0901794433594 401.8715515136719
#
# 0: 480x640 1 face, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7466])
# data: tensor([[319.4823, 204.0150, 474.0378, 404.3022,   1.0000,   0.7466,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([
   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[424.7095, 311.1866, 160.3223, 208.1823]])
# xywhn: tensor([[0.6636, 0.6483, 0.2505, 0.4337]])
# xyxy: tensor([[344.5484, 207.0955, 504.8707, 415.2778]])
# xyxyn: tensor([[0.5384, 0.4314, 0.7889, 0.8652]])
# [[344.54840087890625, 207.09547424316406, 504.87066650390625, 415.2778015136719]]
# 344.54840087890625 207.09547424316406 504.87066650390625 415.2778015136719
#
# 0: 480x640 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8462])
# data: tensor([[337.2361, 207.5944, 495.0321, 416.6391,   1.0000,   0.8462,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[416.1341, 312.1168, 157.7960, 209.0448]])
# xywhn: tensor([[0.6502, 0.6502, 0.2466, 0.4355]])
# xyxy: tensor([[337.2361, 207.5944, 495.0321, 416.6391]])
# xyxyn: tensor([[0.5269, 0.4325, 0.7735, 0.8680]])
# [[337.2361145019531, 207.5943603515625, 495.0321350097656, 416.6391296386719]]
# 337.2361145019531 207.5943603515625 495.0321350097656 416.6391296386719
#
# 0: 480x640 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8547])
# data: tensor([[323.9960, 202.9615, 480.1394, 413.2387,   1.0000,   0.8547,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[402.0677, 308.1001, 156.1434, 210.2772]])
# xywhn: tensor([[0.6282, 0.6419, 0.2440, 0.4381]])
# xyxy: tensor([[323.9960, 202.9615, 480.1394, 413.2387]])
# xyxyn: tensor([[0.5062, 0.4228, 0.7502, 0.8609]])
# [[323.9959716796875, 202.96151733398438, 480.1393737792969, 413.2387390136719]]
# 323.9959716796875 202.96151733398438 480.1393737792969 413.2387390136719
#
# 0: 480x640 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8547])
# data: tensor([[318.9515, 201.0942, 474.5689, 411.7910,   1.0000,   0.8547,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[396.7602, 306.4426, 155.6175, 210.6969]])
# xywhn: tensor([[0.6199, 0.6384, 0.2432, 0.4390]])
# xyxy: tensor([[318.9515, 201.0942, 474.5689, 411.7910]])
# xyxyn: tensor([[0.4984, 0.4189, 0.7415, 0.8579]])
# [[318.95147705078125, 201.0941619873047, 474.5689392089844, 411.791015625]]
# 318.95147705078125 201.0941619873047 474.5689392089844 411.791015625
#
# 0: 480x640 1 face, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7832])
# data: tensor([[305.0531, 207.2097, 461.3482, 413.1824,   1.0000,   0.7832,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[383.2006, 310.1960, 156.2951, 205.9727]])
# xywhn: tensor([[0.5988, 0.6462, 0.2442, 0.4291]])
# xyxy: tensor([[305.0531, 207.2097, 461.3482, 413.1824]])
# xyxyn: tensor([[0.4766, 0.4317, 0.7209, 0.8608]])
# [[305.0531005859375, 207.209716796875, 461.3481750488281, 413.1824035644531]]
# 305.0531005859375 207.209716796875 461.3481750488281 413.1824035644531
#
# 0: 480x640 1 face, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8277])
# data: tensor([[288.1185, 200.1458, 442.0504, 412.5259,   1.0000,   0.8277,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[365.0844, 306.3358, 153.9319, 212.3801]])
# xywhn: tensor([[0.5704, 0.6382, 0.2405, 0.4425]])
# xyxy: tensor([[288.1185, 200.1458, 442.0504, 412.5259]])
# xyxyn: tensor([[0.4502, 0.4170, 0.6907, 0.8594]])
# [[288.11846923828125, 200.1458282470703, 442.05035400390625, 412.52587890625]]
# 288.11846923828125 200.1458282470703 442.05035400390625 412.52587890625
#
# 0: 480x640 1 face, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7737])
# data: tensor([[258.5086, 199.5977, 414.1873, 417.8867,   1.0000,   0.7737,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[336.3480, 308.7422, 155.6787, 218.2890]])
# xywhn: tensor([[0.5255, 0.6432, 0.2432, 0.4548]])
# xyxy: tensor([[258.5086, 199.5977, 414.1873, 417.8867]])
# xyxyn: tensor([[0.4039, 0.4158, 0.6472, 0.8706]])
# [[258.5085754394531, 199.5977325439453, 414.18731689453125, 417.88671875]]
# 258.5085754394531 199.5977325439453 414.18731689453125 417.88671875
#
# 0: 480x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8061])
# data: tensor([[241.1909, 203.2098, 400.9274, 421.6357,   1.0000,   0.8061,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[321.0592, 312.4228, 159.7365, 218.4259]])
# xywhn: tensor([[0.5017, 0.6509, 0.2496, 0.4551]])
# xyxy: tensor([[241.1909, 203.2098, 400.9274, 421.6357]])
# xyxyn: tensor([[0.3769, 0.4234, 0.6264, 0.8784]])
# [[241.19094848632812, 203.20982360839844, 400.92742919921875, 421.63568115234375]]
# 241.19094848632812 203.20982360839844 400.92742919921875 421.63568115234375
#
# 0: 480x640 1 face, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8112])
# data: tensor([[229.0074, 212.1257, 390.9752, 425.2875,   1.0000,   0.8112,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[309.9913, 318.7066, 161.9678, 213.1618]])
# xywhn: tensor([[0.4844, 0.6640, 0.2531, 0.4441]])
# xyxy: tensor([[229.0074, 212.1257, 390.9752, 425.2875]])
# xyxyn: tensor([[0.3578, 0.4419, 0.6109, 0.8860]])
# [[229.0073699951172, 212.12567138671875, 390.9752197265625, 425.2874755859375]]
# 229.0073699951172 212.12567138671875 390.9752197265625 425.2874755859375
#
# 0: 480x640 1 face, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8112])
# data: tensor([[224.7460, 215.5372, 387.6133, 426.5655,   1.0000,   0.8112,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[306.1797, 321.0514, 162.8672, 211.0283]])
# xywhn: tensor([[0.4784, 0.6689, 0.2545, 0.4396]])
# xyxy: tensor([[224.7460, 215.5372, 387.6133, 426.5655]])
# xyxyn: tensor([[0.3512, 0.4490, 0.6056, 0.8887]])
# [[224.7460479736328, 215.5371856689453, 387.61328125, 426.5655212402344]]
# 224.7460479736328 215.5371856689453 387.61328125 426.5655212402344
#
# 0: 480x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7928])
# data: tensor([[220.6582, 210.7590, 384.8858, 426.7556,   1.0000,   0.7928,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[302.7720, 318.7573, 164.2276, 215.9965]])
# xywhn: tensor([[0.4731, 0.6641, 0.2566, 0.4500]])
# xyxy: tensor([[220.6582, 210.7590, 384.8858, 426.7556]])
# xyxyn: tensor([[0.3448, 0.4391, 0.6014, 0.8891]])
# [[220.65821838378906, 210.75904846191406, 384.8858337402344, 426.7555847167969]]
# 220.65821838378906 210.75904846191406 384.8858337402344 426.7555847167969
#
# 0: 480x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8052])
# data: tensor([[220.5570, 216.5345, 382.2727, 423.3203,   1.0000,   0.8052,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[301.4149, 319.9274, 161.7158, 206.7859]])
# xywhn: tensor([[0.4710, 0.6665, 0.2527, 0.4308]])
# xyxy: tensor([[220.5570, 216.5345, 382.2727, 423.3203]])
# xyxyn: tensor([[0.3446, 0.4511, 0.5973, 0.8819]])
# [[220.5569610595703, 216.53448486328125, 382.2727355957031, 423.3203430175781]]
# 220.5569610595703 216.53448486328125 382.2727355957031 423.3203430175781
#
# 0: 480x640 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8205])
# data: tensor([[230.1895, 207.1951, 390.3998, 419.4088,   1.0000,   0.8205,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[310.2947, 313.3019, 160.2103, 212.2137]])
# xywhn: tensor([[0.4848, 0.6527, 0.2503, 0.4421]])
# xyxy: tensor([[230.1895, 207.1951, 390.3998, 419.4088]])
# xyxyn: tensor([[0.3597, 0.4317, 0.6100, 0.8738]])
# [[230.18954467773438, 207.19508361816406, 390.3998107910156, 419.4088134765625]]
# 230.18954467773438 207.19508361816406 390.3998107910156 419.4088134765625

# %%
import cv2
import face_recognition
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Load the video stream
video_path = "C:/Users/pytho/Downloads/face detection[1].mp4"
cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces_rect = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=4, minSize=(30, 30))

        for (x, y, w, h) in faces_rect:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), thickness=2)

        cv2.imshow('Video', frame)

        key = cv2.waitKey(1) & 0xFF

        if key == ord("p"):
            cv2.waitKey(-1)  # Wait indefinitely until any key is pressed
        elif key == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #One with borders

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n-face.pt')

# Load the video stream
video_path = "C:/Users/pytho/Downloads/face detection[1].mp4"
cap = cv2.VideoCapture(video_path)

# Get the frame size
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the two straight lines
line1_x = 70
line2_x = frame_width - 70

# Initialize head count
head_count = 0
# Initialize set to store processed IDs
processed_ids = set()
total_ids = []
# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, conf=0.70, classes=0, persist=True)

        annotated_frame = results[0].plot()
        bbox = results[0].boxes.xyxy.to('cpu').tolist()
        id_tensor = results[0].boxes.id
        id_values = []

        if bbox != []:
            x1, y1, x2, y2 = bbox[0]
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2

            # Draw a circle at the center of the bounding box
            # cv2.circle(annotated_frame, (center_x, center_y), 5, (255, 0, 0), -1)
            if id_tensor is not None:
                id_values = [int(id_item) for id_item in id_tensor.tolist()]
                print("Detected object IDs:", id_values)
            else:
                print("No ID associated with the detected object.")

            

            # Check if the center crosses the two lines
            if center_x < line1_x or center_x > line2_x:
                for id_value in id_values:
                    if id_value not in total_ids:
                        head_count += 1
                        total_ids.append(id_value) 
                # Get the ID of the head
        
                   
            


        cv2.putText(annotated_frame, f'Heads: {head_count}', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        cv2.putText(annotated_frame, f'pid: {total_ids}', (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Draw the two lines
        cv2.line(annotated_frame, (line1_x, 0), (line1_x, frame_height), (0, 255, 0), 2)
        cv2.line(annotated_frame, (line2_x, 0), (line2_x, frame_height), (0, 255, 0), 2)

        cv2.imshow('Video', annotated_frame)

        # Pause the video if 'p' key is pressed
        key = cv2.waitKey(1) & 0xFF

        if key == ord("p"):
            cv2.waitKey(-1)  # Wait indefinitely until any key is pressed
        elif key == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 face, 57.5ms
# Speed: 5.0ms preprocess, 57.5ms inference, 164.7ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 (no detections), 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 19.0ms
# Speed: 3.0ms preprocess, 19.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 1.1ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 1 face, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [1]
#
# 0: 640x384 (no detections), 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.8ms
# Speed: 1.0ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 12.7ms
# Speed: 3.1ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.4ms
# Speed: 1.3ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# No ID associated with the detected object.
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.1ms
# Speed: 2.2ms preprocess, 15.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.6ms
# Speed: 3.1ms preprocess, 14.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.3ms
# Speed: 2.3ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.6ms
# Speed: 2.2ms preprocess, 13.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 1 face, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [2]
#
# 0: 640x384 (no detections), 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 3.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.6ms
# Speed: 2.2ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# No ID associated with the detected object.
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 1.1ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [3]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# ...
#
# 0: 640x384 (no detections), 13.1ms
# Speed: 3.1ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 9.1ms
# Speed: 3.7ms preprocess, 9.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 18.2ms
# Speed: 3.0ms preprocess, 18.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.4ms
# Speed: 3.0ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 14.8ms
# Speed: 3.1ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 15.1ms
# Speed: 3.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 4.1ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.3ms
# Speed: 3.1ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 1 face, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Detected object IDs: [35]
#
# 0: 640x384 (no detections), 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.9ms
# Speed: 3.4ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# No ID associated with the detected object.
#
# 0: 640x384 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.2ms
# Speed: 3.7ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
